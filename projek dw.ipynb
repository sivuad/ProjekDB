# %%
import pandas as pd
import matplotlib.pyplot as plt
import mysql.connector

# %matplotlib inline
plt.style.use('seaborn')

# %%
dt = pd.read_csv('item.csv')
dt
# Out:
#           itemId                 category  \
# 0      100002528  beli-harddisk-eksternal
# 1      100003785  beli-harddisk-eksternal
# 2      100004132  beli-harddisk-eksternal
# 3      100004505  beli-harddisk-eksternal
# 4      100005037  beli-harddisk-eksternal
# ...          ...                      ...
# 10937    9467887    shop-televisi-digital
# 10938    9467898    shop-televisi-digital
# 10939    9467899    shop-televisi-digital
# 10940    9548087    shop-televisi-digital
# 10941    9548767    shop-televisi-digital
#
#                                                     name brandName  \
# 0      TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free B...   Toshiba
# 1      TOSHIBA Full HD Smart LED TV 40" - 40L5650VJ -...   Toshiba
# 2       Samsung 40 Inch Full HD Flat LED Digital TV 4...        LG
# 3              Sharp HD LED TV 24" - LC-24LE175I - Hitam     Sharp
# 4      Lenovo Ideapad 130-15AST LAPTOP MULTIMEDIA I A...    Lenovo
# ...

# %%
#lima data teratas
dt.head()
# Out:
#       itemId                 category  \
# 0  100002528  beli-harddisk-eksternal
# 1  100003785  beli-harddisk-eksternal
# 2  100004132  beli-harddisk-eksternal
# 3  100004505  beli-harddisk-eksternal
# 4  100005037  beli-harddisk-eksternal
#
#                                                 name brandName  \
# 0  TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free B...   Toshiba
# 1  TOSHIBA Full HD Smart LED TV 40" - 40L5650VJ -...   Toshiba
# 2   Samsung 40 Inch Full HD Flat LED Digital TV 4...        LG
# 3          Sharp HD LED TV 24" - LC-24LE175I - Hitam     Sharp
# 4  Lenovo Ideapad 130-15AST LAPTOP MULTIMEDIA I A...    Lenovo
#
#                                                  url    price  averageRating  \
# 0  https://www.lazada.co.id/products/toshiba-smar...  2499000              4
# 1  https://www.lazada.co.id/products/toshiba-full...  3788000              3
# 2  https://www.lazada.co.id/products/samsung-40-i...  3850000              3
# ...

# %%
#deskripsi 
dt.describe()
# Out:
#              itemId         price  averageRating  totalReviews
# count  1.094200e+04  1.094200e+04   10942.000000  10942.000000
# mean   2.936823e+08  3.020219e+06       4.171632     27.369494
# std    2.090568e+08  6.681453e+06       1.032055    260.253817
# min    6.068000e+03  1.000000e+03       1.000000      1.000000
# 25%    1.082924e+08  7.920000e+04       4.000000      1.000000
# 50%    3.540792e+08  1.095000e+06       4.000000      2.000000
# 75%    4.527141e+08  3.959000e+06       5.000000      7.000000
# max    7.242170e+08  2.750000e+08       5.000000   9631.000000

# %%
dt.category.value_counts()
# Out:
# beli-harddisk-eksternal    4422
# jual-flash-drives          3318
# beli-smart-tv              1290
# shop-televisi-digital      1211
# beli-laptop                 701
# Name: category, dtype: int64

# %%
#Koneksi databse
db = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd=""
)
if db.is_connected():
    print("hasil terhubung ke Database")
# Out:
# hasil terhubung ke Database

# %%
cursor = db.cursor()
cursor.execute("CREATE DATABASE lazada")
print("Database berhasil dibuat")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-12-c8b5076b0977> in <module>
#       1 cursor = db.cursor()
# ----> 2 cursor.execute("CREATE DATABASE lazada")
#       3 print("Database berhasil dibuat")
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     549         else:
#     550             try:
# --> 551                 self._handle_result(self._connection.cmd_query(stmt))
#     552             except errors.InterfaceError:
#     553                 if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     488         if not isinstance(query, bytes):
#     489             query = query.encode('utf-8')
# ...

# %%
cursor.execute("use lazada")
cursor.execute("DROP TABLE if exists kategori")
cursor.execute("DROP TABLE if exists merek")
cursor.execute("DROP TABLE if exists barang")
cursor.execute("create table kategori(id_kategori int primary key, kategori varchar(100) not null)")
cursor.execute("create table merek(id_merek int primary key, nama_merek varchar(100) not null)")
cursor.execute("create table barang(id_barang int primary key, nama_brng varchar(100) not null)")
